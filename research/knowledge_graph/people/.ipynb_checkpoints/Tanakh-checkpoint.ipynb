# %%
import unicodecsv
import django
import codecs
import json
django.setup()
from sefaria.model import *

# %%
with codecs.open("wikidata_people_final.json", "rb", encoding='utf8') as fin:
    wiki = json.load(fin)

# %%
wiki[u'Q10271944'].keys()
# Out:
# [u'presentIn',
#  u'position held',
#  u'name',
#  u'sex or gender',
#  u'present in work',
#  u'heName',
#  u'aliases']

# %%
with open("aspaklaria_people.csv", "rb") as fin:
    csv = unicodecsv.DictReader(fin)
    asp = []
    for row in csv:
        asp += [row]
